# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#load customer data
customers = pd.read_table('customers_data.csv')
customers.head()
# Out:
#    customer  accountid  workingbalance openingdate Restriciton Code  \
# 0  15045151   14607892           88.01  2016-06-10               25
# 1  16273893   11143214        25293.31  2016-10-28              NaN
# 2  17261366   15599591         3328.29  2016-09-22         19$23$25
# 3  14006532   17841524         2110.85  2021-01-21              NaN
# 4  19087216   11994865           88.01  2016-06-15               25
#
#               address email_1 account_status Maxtransdate  \
# 0                 NaN     NaN        Dormant   2020-10-27
# 1       IJESHA, LAGOS     NaN         Active   2022-03-23
# 2    AJEGUNLE AJEROMI     NaN        Dormant   2020-10-14
# 3  STOP KIRIKIRI TOWN     NaN         Active   2022-03-08
# 4         OLODI APAPA     NaN        Dormant   2020-10-20
#
#        product_group_desc        customer_type          region  \
# 0  Savings Accounts Group  Individual Customer  APAPA & BEYOND
# 1  Savings Accounts Group  Individual Customer  APAPA & BEYOND
# 2  Savings Accounts Group  Individual Customer  APAPA & BEYOND
# 3  Current Accounts Group  Individual Customer  APAPA & BEYOND
# 4  Savings Accounts Group  Individual Customer  APAPA & BEYOND
#
#                            sector card_status  onebank  onepay  ussd
# 0  ADMIN AND SUPPORT SERVICE ACT.         NaN        0       0     0
# 1                         GENERAL      Active        0       0     1
# 2                         GENERAL         NaN        0       0     0
# 3                         GENERAL         NaN        0       0     0
# 4  ADMIN AND SUPPORT SERVICE ACT.         NaN        0       0     0

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer            5000 non-null   int64
#  1   accountid           5000 non-null   int64
#  2   workingbalance      5000 non-null   float64
#  3   openingdate         5000 non-null   object
#  4   Restriciton Code    3532 non-null   object
#  5   address             4317 non-null   object
#  6   email_1             1586 non-null   object
#  7   account_status      5000 non-null   object
#  8   Maxtransdate        5000 non-null   object
#  9   product_group_desc  4931 non-null   object
#  10  customer_type       5000 non-null   object
#  11  region              5000 non-null   object
#  12  sector              5000 non-null   object
#  13  card_status         1873 non-null   object
#  14  onebank             5000 non-null   int64
#  15  onepay              5000 non-null   int64
#  16  ussd                5000 non-null   int64
# dtypes: float64(1), int64(5), object(11)
# memory usage: 664.2+ KB

# %%
customers.shape
# Out:
# (5000, 17)

# %%
customers.describe()
# Out:
#            customer     accountid  workingbalance      onebank       onepay  \
# count  5.000000e+03  5.000000e+03    5.000000e+03  5000.000000  5000.000000
# mean   1.501572e+07  1.496175e+07   -3.110929e+05     0.094400     0.169400
# std    2.917798e+06  2.895771e+06    2.796984e+07     0.292414     0.375142
# min    1.000006e+07  1.000002e+07   -1.972557e+09     0.000000     0.000000
# 25%    1.245201e+07  1.243579e+07    9.337750e+01     0.000000     0.000000
# 50%    1.499100e+07  1.493074e+07    9.578150e+02     0.000000     0.000000
# 75%    1.754916e+07  1.747498e+07    5.389932e+03     0.000000     0.000000
# max    1.999880e+07  1.999780e+07    1.020330e+08     1.000000     1.000000
#
#               ussd
# count  5000.000000
# mean      0.178600
# std       0.383055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
customers['account_status'].value_counts()
# Out:
# account_status
# Dormant     3260
# Active      1456
# Inactive     284
# Name: count, dtype: int64

# %%
customers['product_group_desc'].value_counts()
# Out:
# product_group_desc
# Savings Accounts Group               3769
# Current Accounts Group                858
# Domiciliary Current Account Group     141
# Retail Loans Individual Group          61
# Domiciliary Savings Account Group      53
# Term Deposits Group                    26
# Corporate Loans Group                  17
# HRM Loans Group                         4
# Small Business Loans Group              1
# Customer Collection a/c Group           1
# Name: count, dtype: int64

# %%
customers['customer_type'].value_counts()
# Out:
# customer_type
# Individual Customer                4106
# Corporate Customer                  332
# Salary Customer                     183
# Minor                               147
# Enterprise Customer                 100
# MSME                                 39
# Individual Staff                     38
# Youth Corper                         20
# Internal Customer                    15
# Not for Profit                        7
# EMBASSY/HIGH COMMISSION               4
# DSE                                   3
# Joint Customers                       2
# Trainee                               1
# Government/MDA Customer (State)       1
# Student                               1
# Government/MDA Customer (FGN)         1
# Name: count, dtype: int64

# %%
customers['sector'].value_counts()
# Out:
# sector
# GENERAL                              4046
# ADMIN AND SUPPORT SERVICE ACT.        348
# GENERAL COMMERCE                      180
# OIL AND GAS                           103
# TRANSPORTATION AND STORAGE             49
# AGRICULTURE                            47
# FINANCE AND INSURANCE                  43
# EDUCATION                              40
# INFORMATION AND COMMUNICATION          26
# GOVERNMENT                             26
# CONSTRUCTION                           19
# PROF SCIENTIFIC AND TECH ACT.          17
# REAL ESTATE                            15
# MANUFACTURING                          14
# Cooperative Cluster                     9
# HEALTH                                  6
# Human health and social work act.       5
# NOT FOR PROFIT                          5
# ARTS ENTERTAINMENT AND RECREATION       1
# POWER AND ENERGY                        1
# Name: count, dtype: int64

# %%
customers['onebank'].value_counts()
# Out:
# onebank
# 0    4528
# 1     472
# Name: count, dtype: int64

# %%
customers['onepay'].value_counts()
# Out:
# onepay
# 0    4153
# 1     847
# Name: count, dtype: int64

# %%
customers['ussd'].value_counts()
# Out:
# ussd
# 0    4107
# 1     893
# Name: count, dtype: int64

# %%
customers['card_status'].value_counts()
# Out:
# card_status
# Active        1479
# Expired        312
# Restricted      82
# Name: count, dtype: int64

# %%
customers.isnull().sum()
# Out:
# customer                 0
# accountid                0
# workingbalance           0
# openingdate              0
# Restriciton Code      1468
# address                683
# email_1               3414
# account_status           0
# Maxtransdate             0
# product_group_desc      69
# customer_type            0
# region                   0
# sector                   0
# card_status           3127
# onebank                  0
# onepay                   0
# ussd                     0
# dtype: int64

# %%
customers = customers.dropna()
customers
# Out:
#       customer  accountid  workingbalance openingdate Restriciton Code  \
# 7     18469974   19019509          912.11  2014-06-05               25
# 12    10443609   11737643            0.00  2018-11-28               14
# 22    10299071   13039386        10362.50  2014-06-04               22
# 66    16309904   19762902           59.66  2016-10-04            19$24
# 85    18889987   11597175        50339.23  2016-08-18               25
# ...        ...        ...             ...         ...              ...
# 4906  19621458   13386451            4.47  2016-11-01             1$25
# 4917  10848243   18115303         3698.54  2014-01-22               25
# 4920  11662561   14512144         4371.88  2012-08-08               22
# 4932  12024897   17777006         7181.44  2015-08-14               22
# 4936  19759367   10403769          323.62  2008-06-17               22
#
#                               address                  email_1 account_status  \
# 7                         ABEBI CLOSE  ogdurrbgzt@sterling.com        Dormant
# 12    7 UNITY ROAD AGUNGI LEKKI LAGOS  xpakcnlhgd@sterling.com         Active
# 22                              LAGOS  vryigtnaay@sterling.com        Dormant
# 66                              KETU,  lwvckfmrhh@sterling.com        Dormant
# 85                       IKOYI,LAGOS.  cpvlqjrdhy@sterling.com       Inactive
# ...                               ...                      ...            ...
# 4906                   SURULERE,LAGOS  thhtfqedqz@sterling.com        Dormant
# 4917     MAZA MAZA B.STP AMUWO ODOFIN  kocxfodsos@sterling.com        Dormant
# 4920                            LAGOS  dxkckxsorx@sterling.com        Dormant
# 4932                     B/STOP APAPA  kgpoujqvpk@sterling.com        Dormant
# 4936      LASU-IBA ROAD IGANDO,LAGOS.  bhyatpgiyn@sterling.com        Dormant
#
#      Maxtransdate                 product_group_desc        customer_type  \
# 7      2020-10-13             Savings Accounts Group  Individual Customer
# 12     2018-11-28             Current Accounts Group  Individual Customer
# 22     2018-08-20             Current Accounts Group      Salary Customer
# 66     2017-01-10  Domiciliary Savings Account Group  Individual Customer
# 85     2021-07-19             Savings Accounts Group  Individual Customer
# ...           ...                                ...                  ...
# 4906   2020-10-16             Savings Accounts Group  Individual Customer
# 4917   2020-10-15             Savings Accounts Group  Individual Customer
# 4920   2016-04-07             Current Accounts Group   Corporate Customer
# 4932   2018-04-26             Savings Accounts Group  Individual Customer
# 4936   2020-05-27             Savings Accounts Group  Individual Customer
#
#               region        sector card_status  onebank  onepay  ussd
# 7     APAPA & BEYOND       GENERAL      Active        0       1     0
# 12    APAPA & BEYOND       GENERAL      Active        1       1     0
# 22    APAPA & BEYOND       GENERAL     Expired        0       0     0
# 66    APAPA & BEYOND       GENERAL     Expired        0       1     0
# 85    APAPA & BEYOND       GENERAL      Active        0       0     0
# ...              ...           ...         ...      ...     ...   ...
# 4906  APAPA & BEYOND  CONSTRUCTION      Active        1       0     0
# 4917  APAPA & BEYOND       GENERAL     Expired        0       0     0
# 4920  APAPA & BEYOND       GENERAL     Expired        0       0     0
# 4932  APAPA & BEYOND       GENERAL     Expired        0       0     0
# 4936  APAPA & BEYOND       GENERAL     Expired        0       1     1
#
# [289 rows x 17 columns]

# %%
customers.duplicated().sum()
# Out:
# 0

# %%
customers['account_status'].value_counts().plot.bar()
plt.title('Account Status')
# Out:
# Text(0.5, 1.0, 'Account Status')

# %%
customers['customer_type'].value_counts().plot.bar()
plt.title('Customer Type')
# Out:
# Text(0.5, 1.0, 'Customer Type')

# %%
customers['card_status'].value_counts().plot.bar()
plt.title('Card Status')
# Out:
# Text(0.5, 1.0, 'Card Status')

# %%
customers['sector'].value_counts().plot.bar()
plt.title('Sector')
# Out:
# Text(0.5, 1.0, 'Sector')

# %%
customer_type = pd.crosstab(customers['customer_type'],customers['account_status'])
customer_type
# Out:
# account_status       Active  Dormant  Inactive
# customer_type
# Corporate Customer        3       18         2
# Enterprise Customer       1        5         0
# Individual Customer      21      173        30
# Individual Staff          3        3         0
# MSME                      1        2         0
# Minor                     0        2         1
# Salary Customer           4       15         2
# Youth Corper              0        3         0

# %%
region = pd.crosstab(customers['region'],customers['account_status'])
region.div(region.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='region'>

# %%
card_status = pd.crosstab(customers['card_status'],customers['account_status'])
card_status.div(card_status.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='card_status'>

# %%
onebank = pd.crosstab(customers['onebank'],customers['account_status'])
onebank.div(onebank.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='onebank'>

# %%
onepay = pd.crosstab(customers['onepay'],customers['account_status'])
onepay.div(onepay.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='onepay'>

# %%
ussd = pd.crosstab(customers['ussd'],customers['account_status'])
ussd.div(ussd.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='ussd'>

# %%
product_group = pd.crosstab(customers['product_group_desc'],customers['account_status'])
product_group.div(product_group.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='product_group_desc'>

# %%
#Load the second data
transactions_data = pd.read_csv("transactions_data.csv")
transactions_data.head()
# Out:
#    customer  accountid  AMOUNT_LCY      Trans_ID          Trans_timestamp  \
# 0  18354812   19888479   321685.00  FT202730YK10  2020-09-29 10:16:04.000
# 1  12174614   16476167     1555.40  FT202661P8Q7  2020-09-22 15:47:31.000
# 2  13975321   15133256   331922.37  FT20274MBLN1  2020-09-30 15:05:40.997
# 3  13268397   13323967    28280.00  FT20266W5M7H  2020-09-22 07:30:57.000
# 4  11773959   14430794   363398.00  FT20268S7T8C  2020-09-24 11:08:32.000
#
#   deb_cre_ind                                          narrative  \
# 0           C  CHOICE INTERNATIONAL FORWARDING NIG?EMEKA LINU...
# 1           C  BANK?NIP From 11000720092216005928289544?8107 ...
# 2           C              BANK]SEPTEMBER SALARY 030202093421349
# 3           C  BANK?NIP From 00001420092208270929929956?7597 ...
# 4           C  BANK?NIP From 00001520092411552900116649?4596 ...
#
#   transactiondescription
# 0            TRANSFER IN
# 1            TRANSFER IN
# 2            TRANSFER IN
# 3            TRANSFER IN
# 4            TRANSFER IN

# %%
transactions_data
# Out:
#         customer  accountid  AMOUNT_LCY      Trans_ID  \
# 0       18354812   19888479   321685.00  FT202730YK10
# 1       12174614   16476167     1555.40  FT202661P8Q7
# 2       13975321   15133256   331922.37  FT20274MBLN1
# 3       13268397   13323967    28280.00  FT20266W5M7H
# 4       11773959   14430794   363398.00  FT20268S7T8C
# ...          ...        ...         ...           ...
# 111065  14452547   17601508     5656.00  FT20272S000S
# 111066  14576926   14200268    14140.00  FT20272PCHBH
# 111067  11239761   18120131     5656.00  FT20260SLYXQ
# 111068  11823224   15747686    56560.00  FT20267TZ7LT
# 111069  13412602   17408325   240380.00           NaN
#
#                 Trans_timestamp deb_cre_ind  \
# 0       2020-09-29 10:16:04.000           C
# 1       2020-09-22 15:47:31.000           C
# 2       2020-09-30 15:05:40.997           C
# 3       2020-09-22 07:30:57.000           C
# 4       2020-09-24 11:08:32.000           C
# ...                         ...         ...
# 111065  2020-09-26 10:28:36.000           D
# 111066  2020-09-27 15:26:47.000           D
# 111067  2020-09-15 20:31:21.000           D
# 111068  2020-09-23 07:33:06.000           C
# 111069                     2020         NaN
#
#                                                 narrative  \
# 0       CHOICE INTERNATIONAL FORWARDING NIG?EMEKA LINU...
# 1       BANK?NIP From 11000720092216005928289544?8107 ...
# 2                   BANK]SEPTEMBER SALARY 030202093421349
# 3       BANK?NIP From 00001420092208270929929956?7597 ...
# 4       BANK?NIP From 00001520092411552900116649?4596 ...
# ...                                                   ...
# 111065  E-OPS- MASTERCARD POS PAYABLE(ROU)?OTHER BANK ...
# 111066  INTESWITCH TSS ACC?OTHER BANK TERMINAL - ?PAYC...
# 111067  NIBSS INSTANT PAYMENT TSS?Trf 4000.00 frm JOSH...
# 111068  CASH IN ATM?STERLING BANK TERMINAL - ?26B CREE...
# 111069                                                NaN
#
#            transactiondescription
# 0                     TRANSFER IN
# 1                     TRANSFER IN
# 2                     TRANSFER IN
# 3                     TRANSFER IN
# 4                     TRANSFER IN
# ...                           ...
# 111065     POINT OF SALE PURCHASE
# 111066  BILL PYMNT-FUNDS TRANSFER
# 111067                      TRF :
# 111068            CASH WITHDRAWAL
# 111069                        NaN
#
# [111070 rows x 8 columns]

# %%
transactions_data.shape
# Out:
# (111070, 8)

# %%
transactions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111070 entries, 0 to 111069
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer                111070 non-null  int64
#  1   accountid               111070 non-null  int64
#  2   AMOUNT_LCY              111070 non-null  float64
#  3   Trans_ID                108916 non-null  object
#  4   Trans_timestamp         111070 non-null  object
#  5   deb_cre_ind             111069 non-null  object
#  6   narrative               110796 non-null  object
#  7   transactiondescription  111069 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.8+ MB

# %%
transactions_data["Trans_timestamp"] = pd.to_datetime(transactions_data['Trans_timestamp'], errors= 'coerce')

# %%
missing_timestamps = transactions_data['Trans_timestamp'].isna().sum()
print(f"Number of missing timestamps: {missing_timestamps}")
# Out:
# Number of missing timestamps: 1

# %%
if missing_timestamps > 0:
    missing_indices = transactions_data[transactions_data['Trans_timestamp'].isna()].index.tolist()
    print(f"Indices of rows with missing timestamps: {missing_indices}")
    # Inspect the data at these indices to understand why the conversion failed
    print(transactions_data.iloc[missing_indices]['Trans_timestamp'])
# Out:
# Indices of rows with missing timestamps: [111069]
# 111069   NaT
# Name: Trans_timestamp, dtype: datetime64[ns]

# %%
transactions_data.nunique()
# Out:
# customer                    7926
# accountid                   8189
# AMOUNT_LCY                  9314
# Trans_ID                  106773
# Trans_timestamp           104071
# deb_cre_ind                    2
# narrative                  78212
# transactiondescription        24
# dtype: int64

# %%
transactions_data["Trans_timestamp"].dt.day
# Out:
# 0         29.0
# 1         22.0
# 2         30.0
# 3         22.0
# 4         24.0
#           ...
# 111065    26.0
# 111066    27.0
# 111067    15.0
# 111068    23.0
# 111069     NaN
# Name: Trans_timestamp, Length: 111070, dtype: float64

# %%
transactions_data.describe()
# Out:
#            customer     accountid    AMOUNT_LCY                Trans_timestamp
# count  1.110700e+05  1.110700e+05  1.110700e+05                         111069
# mean   1.505663e+07  1.507085e+07  2.564217e+05  2020-09-23 02:25:02.295264512
# min    1.000006e+07  1.000291e+07  1.000000e-02            2020-09-04 19:19:17
# 25%    1.262833e+07  1.263245e+07  2.828000e+03            2020-09-19 06:15:00
# 50%    1.509406e+07  1.498136e+07  7.777000e+03            2020-09-23 14:29:30
# 75%    1.758853e+07  1.765241e+07  2.828000e+04            2020-09-27 15:24:28
# max    1.999980e+07  1.999918e+07  1.398003e+09     2020-10-01 05:54:21.997000
# std    2.879331e+06  2.912310e+06  7.469305e+06                            NaN

# %%
transactions_data["deb_cre_ind"].value_counts()
# Out:
# deb_cre_ind
# D    78904
# C    32165
# Name: count, dtype: int64

# %%
transactions_data["transactiondescription"].value_counts()
# Out:
# transactiondescription
# TRF :                            43148
# TRANSFER IN                      27672
# CASH WITHDRAWAL                  16732
# POINT OF SALE PURCHASE           11805
# BILL PYMNT-FUNDS TRANSFER         6481
# DEPOSIT CASH (LOCAL CURRENCY)     1783
# TRANSFER OUT                      1511
# NEFT CREDITS                       726
# ETRANZACT PAYMENT                  417
# AA LOAN REPAYMENT                  396
# STANDING ORDER                     151
# CASH WITHDRAWAL(LOCAL CCY)          49
# ACCOUNTS TRANSFER                   48
# DRAFT COMMISSION + VAT              43
# AA DEBIT SETTLE ARRANGEMENT         25
# OUTWARD CHEQUE PAYMENT              22
# CHEQUE DEPOSIT (INHOUSE)            20
# CHEQUE                              18
# CASH WITHDRAWAL FOREIGN CCY          7
# DEPOSIT WITHDRAWAL (TRANSFER)        6
# NEW DEPOSIT                          4
# STERLING INWARD TELEX PAYMENT        2
# CREDIT ARRANGEMENT                   2
# AA LOAN PAYOFF                       1
# Name: count, dtype: int64

# %%
transactions_data.isna().sum()
# Out:
# customer                     0
# accountid                    0
# AMOUNT_LCY                   0
# Trans_ID                  2154
# Trans_timestamp              1
# deb_cre_ind                  1
# narrative                  274
# transactiondescription       1
# dtype: int64

# %%
transactions_data1 = transactions_data.dropna(how = 'all')

# %%
transactions_data1
# Out:
#         customer  accountid  AMOUNT_LCY      Trans_ID         Trans_timestamp  \
# 0       18354812   19888479   321685.00  FT202730YK10 2020-09-29 10:16:04.000
# 1       12174614   16476167     1555.40  FT202661P8Q7 2020-09-22 15:47:31.000
# 2       13975321   15133256   331922.37  FT20274MBLN1 2020-09-30 15:05:40.997
# 3       13268397   13323967    28280.00  FT20266W5M7H 2020-09-22 07:30:57.000
# 4       11773959   14430794   363398.00  FT20268S7T8C 2020-09-24 11:08:32.000
# ...          ...        ...         ...           ...                     ...
# 111065  14452547   17601508     5656.00  FT20272S000S 2020-09-26 10:28:36.000
# 111066  14576926   14200268    14140.00  FT20272PCHBH 2020-09-27 15:26:47.000
# 111067  11239761   18120131     5656.00  FT20260SLYXQ 2020-09-15 20:31:21.000
# 111068  11823224   15747686    56560.00  FT20267TZ7LT 2020-09-23 07:33:06.000
# 111069  13412602   17408325   240380.00           NaN                     NaT
#
#        deb_cre_ind                                          narrative  \
# 0                C  CHOICE INTERNATIONAL FORWARDING NIG?EMEKA LINU...
# 1                C  BANK?NIP From 11000720092216005928289544?8107 ...
# 2                C              BANK]SEPTEMBER SALARY 030202093421349
# 3                C  BANK?NIP From 00001420092208270929929956?7597 ...
# 4                C  BANK?NIP From 00001520092411552900116649?4596 ...
# ...            ...                                                ...
# 111065           D  E-OPS- MASTERCARD POS PAYABLE(ROU)?OTHER BANK ...
# 111066           D  INTESWITCH TSS ACC?OTHER BANK TERMINAL - ?PAYC...
# 111067           D  NIBSS INSTANT PAYMENT TSS?Trf 4000.00 frm JOSH...
# 111068           C  CASH IN ATM?STERLING BANK TERMINAL - ?26B CREE...
# 111069         NaN                                                NaN
#
#            transactiondescription
# 0                     TRANSFER IN
# 1                     TRANSFER IN
# 2                     TRANSFER IN
# 3                     TRANSFER IN
# 4                     TRANSFER IN
# ...                           ...
# 111065     POINT OF SALE PURCHASE
# 111066  BILL PYMNT-FUNDS TRANSFER
# 111067                      TRF :
# 111068            CASH WITHDRAWAL
# 111069                        NaN
#
# [111070 rows x 8 columns]

# %%
transactions_data.duplicated().sum()
# Out:
# 0

# %%
transactions_data1["deb_cre_ind"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='deb_cre_ind'>

# %%
transactions_data1.boxplot(column ='AMOUNT_LCY')
# Out:
# <Axes: >

# %%
#Merge Data
customers_transactions_data = pd.merge(transactions_data, customers, how="inner", on=["customer", "accountid"])

# %%
transactions_data.accountid.isin(customers.accountid.tolist()).sum()
# Out:
# 144

# %%
customers_transactions_data
# Out:
#      customer  accountid  AMOUNT_LCY      Trans_ID     Trans_timestamp  \
# 0    12785837   15214720    14140.00  FT20269BXS37 2020-09-25 12:42:41
# 1    12785837   15214720    14140.00  FT2026278N52 2020-09-18 14:32:06
# 2    12785837   15214720    56560.00  FT20265L1Q1M 2020-09-19 06:58:51
# 3    12785837   15214720    14140.00  FT2026226RKS 2020-09-18 14:35:18
# 4    12785837   15214720    14140.00  FT202624N67V 2020-09-18 14:32:58
# ..        ...        ...         ...           ...                 ...
# 139  13856649   11760776    21492.80  FT20274SNG51 2020-09-30 14:55:03
# 140  13856649   11760776    14140.00  FT2025482FYY 2020-09-10 10:11:00
# 141  13856649   11760776    14493.50  FT2025817XVG 2020-09-14 14:11:15
# 142  19000318   11100453    25237.47  FT202585LWTG 2020-09-14 07:42:02
# 143  17512656   15772024    84840.00  FT20251PWLW9 2020-09-07 12:03:23
#
#     deb_cre_ind                                          narrative  \
# 0             C  BANK?NIP From 00001320092513030400017863?9758 ...
# 1             D  E-OPS- MASTERCARD ATM PAYABLE(ROU)?OTHER BANK ...
# 2             D  E-OPS- MASTERCARD POS PAYABLE(ROU)?OTHER BANK ...
# 3             D  E-OPS- MASTERCARD ATM PAYABLE(ROU)?OTHER BANK ...
# 4             D  E-OPS- MASTERCARD ATM PAYABLE(ROU)?OTHER BANK ...
# ..          ...                                                ...
# 139           C  BANK]NIP From 00001620093014200400000649]5351 ...
# 140           D  E-OPS- MASTERCARD ATM PAYABLE(ROU)?OTHER BANK ...
# 141           D  E-OPS- MASTERCARD POS PAYABLE(ROU)?OTHER BANK ...
# 142           D                                Retail Loan -Specta
# 143           D  INTESWITCH TSS ACC?OTHER BANK TERMINAL - ?WT;A...
#
#         transactiondescription  workingbalance openingdate  ...  \
# 0                  TRANSFER IN         1600.38  2015-01-12  ...
# 1              CASH WITHDRAWAL         1600.38  2015-01-12  ...
# 2       POINT OF SALE PURCHASE         1600.38  2015-01-12  ...
# 3              CASH WITHDRAWAL         1600.38  2015-01-12  ...
# 4              CASH WITHDRAWAL         1600.38  2015-01-12  ...
# ..                         ...             ...         ...  ...
# 139                TRANSFER IN           33.62  2017-02-07  ...
# 140            CASH WITHDRAWAL           33.62  2017-02-07  ...
# 141     POINT OF SALE PURCHASE           33.62  2017-02-07  ...
# 142          AA LOAN REPAYMENT          -72.75  2015-10-13  ...
# 143  BILL PYMNT-FUNDS TRANSFER         1442.82  2018-05-25  ...
#
#     account_status Maxtransdate      product_group_desc        customer_type  \
# 0          Dormant   2020-10-08  Savings Accounts Group  Individual Customer
# 1          Dormant   2020-10-08  Savings Accounts Group  Individual Customer
# 2          Dormant   2020-10-08  Savings Accounts Group  Individual Customer
# 3          Dormant   2020-10-08  Savings Accounts Group  Individual Customer
# 4          Dormant   2020-10-08  Savings Accounts Group  Individual Customer
# ..             ...          ...                     ...                  ...
# 139       Inactive   2021-07-05  Savings Accounts Group                Minor
# 140       Inactive   2021-07-05  Savings Accounts Group                Minor
# 141       Inactive   2021-07-05  Savings Accounts Group                Minor
# 142         Active   2022-01-24  Current Accounts Group  Individual Customer
# 143         Active   2022-01-04  Current Accounts Group  Enterprise Customer
#
#              region            sector card_status onebank onepay ussd
# 0    APAPA & BEYOND           GENERAL      Active       0      0    0
# 1    APAPA & BEYOND           GENERAL      Active       0      0    0
# 2    APAPA & BEYOND           GENERAL      Active       0      0    0
# 3    APAPA & BEYOND           GENERAL      Active       0      0    0
# 4    APAPA & BEYOND           GENERAL      Active       0      0    0
# ..              ...               ...         ...     ...    ...  ...
# 139  APAPA & BEYOND           GENERAL     Expired       0      1    1
# 140  APAPA & BEYOND           GENERAL     Expired       0      1    1
# 141  APAPA & BEYOND           GENERAL     Expired       0      1    1
# 142  APAPA & BEYOND           GENERAL      Active       0      0    0
# 143  APAPA & BEYOND  GENERAL COMMERCE      Active       0      0    0
#
# [144 rows x 23 columns]

# %%
customers.customer.nunique()
# Out:
# 230

# %%
customers_transactions_data["customer"].value_counts()
# Out:
# customer
# 18857196    31
# 10253790    22
# 17170208    17
# 12785837    16
# 15148473    10
# 15829731     8
# 12617138     6
# 10731434     6
# 19315180     4
# 13856649     3
# 18595965     3
# 19823412     3
# 17718048     2
# 16367115     2
# 19916508     2
# 13339743     2
# 11414891     1
# 16679687     1
# 14860237     1
# 10656787     1
# 17106013     1
# 19000318     1
# 17512656     1
# Name: count, dtype: int64

# %%
customers_transactions_data.shape
# Out:
# (144, 23)

# %%
customers_transactions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer                144 non-null    int64
#  1   accountid               144 non-null    int64
#  2   AMOUNT_LCY              144 non-null    float64
#  3   Trans_ID                144 non-null    object
#  4   Trans_timestamp         144 non-null    datetime64[ns]
#  5   deb_cre_ind             144 non-null    object
#  6   narrative               144 non-null    object
#  7   transactiondescription  144 non-null    object
#  8   workingbalance          144 non-null    float64
#  9   openingdate             144 non-null    object
#  10  Restriciton Code        144 non-null    object
#  11  address                 144 non-null    object
#  12  email_1                 144 non-null    object
#  13  account_status          144 non-null    object
#  14  Maxtransdate            144 non-null    object
#  15  product_group_desc      144 non-null    object
#  16  customer_type           144 non-null    object
#  17  region                  144 non-null    object
#  18  sector                  144 non-null    object
#  19  card_status             144 non-null    object
#  20  onebank                 144 non-null    int64
#  21  onepay                  144 non-null    int64
#  22  ussd                    144 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(15)
# memory usage: 26.0+ KB

# %%
customers_transactions_data.duplicated().sum()
# Out:
# 0

# %%
customers_transactions_data["accountid"].value_counts().sum()
# Out:
# 144

# %%
customers_transactions_data["customer"].value_counts().sum()
# Out:
# 144

# %%
customers_transactions_data["customer"].value_counts()
# Out:
# customer
# 18857196    31
# 10253790    22
# 17170208    17
# 12785837    16
# 15148473    10
# 15829731     8
# 12617138     6
# 10731434     6
# 19315180     4
# 13856649     3
# 18595965     3
# 19823412     3
# 17718048     2
# 16367115     2
# 19916508     2
# 13339743     2
# 11414891     1
# 16679687     1
# 14860237     1
# 10656787     1
# 17106013     1
# 19000318     1
# 17512656     1
# Name: count, dtype: int64

# %%
region = pd.crosstab(customers_transactions_data['region'],customers_transactions_data['account_status'])
region.div(region.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='region'>

# %%
customer_type = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['account_status'])
customer_type.div(customer_type.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='customer_type'>

# %%
customer_type1 = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['account_status'])
customer_type1
# Out:
# account_status       Active  Dormant  Inactive
# customer_type
# Corporate Customer        0        1         0
# Enterprise Customer       1        0         0
# Individual Customer       3       61        65
# MSME                      0        1         0
# Minor                     0        0         3
# Salary Customer           0        0         1
# Youth Corper              0        8         0

# %%
customers_transactions_data["customer_type"].value_counts()
# Out:
# customer_type
# Individual Customer    129
# Youth Corper             8
# Minor                    3
# Corporate Customer       1
# MSME                     1
# Salary Customer          1
# Enterprise Customer      1
# Name: count, dtype: int64

# %%
grouped = customers_transactions_data.groupby('workingbalance')
grouped

# %%
grouped['workingbalance'].agg(np.mean)
# Out:
# workingbalance
# -2392833.78     -2392833.78
# -72.75               -72.75
# -3.56                 -3.56
#  2.22                  2.22
#  10.79                10.79
#  12.30                12.30
#  23.83                23.83
#  33.62                33.62
#  54.47                54.47
#  186.89              186.89
#  503.74              503.74
#  513.11              513.11
#  679.34              679.34
#  1071.27            1071.27
#  1154.14            1154.14
#  1442.82            1442.82
#  1600.38            1600.38
#  5128.69            5128.69
#  90613.77          90613.77
#  126571.13        126571.13
#  211979.95        211979.95
#  13558571.85    13558571.85
#  16193655.11    16193655.11
# Name: workingbalance, dtype: float64

# %%
plt.hist(customers_transactions_data.workingbalance.values)
# Out:
# (array([  1., 137.,   0.,   0.,   0.,   0.,   0.,   0.,   2.,   4.]),
#  array([-2392833.78 ,  -534184.891,  1324463.998,  3183112.887,
#          5041761.776,  6900410.665,  8759059.554, 10617708.443,
#         12476357.332, 14335006.221, 16193655.11 ]),
#  <BarContainer object of 10 artists>)

# %%
customer_type_cardstatus = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['card_status'])
customer_type_cardstatus.div(customer_type.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='customer_type'>

# %%
customer_type_cardstatus1 = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['card_status'])
customer_type_cardstatus1
# Out:
# card_status          Active  Expired  Restricted
# customer_type
# Corporate Customer        1        0           0
# Enterprise Customer       1        0           0
# Individual Customer     116        7           6
# MSME                      1        0           0
# Minor                     0        3           0
# Salary Customer           1        0           0
# Youth Corper              8        0           0

# %%
cardstatus_accountstatus = pd.crosstab(customers_transactions_data['card_status'],customers_transactions_data['account_status'])
cardstatus_accountstatus.div(card_status.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='card_status'>

# %%
cardstatus_accountstatus1 = pd.crosstab(customers_transactions_data['card_status'],customers_transactions_data['account_status'])
cardstatus_accountstatus1
# Out:
# account_status  Active  Dormant  Inactive
# card_status
# Active               2       66        60
# Expired              0        1         9
# Restricted           2        4         0

# %%
customer_type_ussd = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['ussd'])
customer_type_ussd.div(customer_type.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='customer_type'>

# %%
customer_type_ussd1 = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['ussd'])
customer_type_ussd1
# Out:
# ussd                  0   1
# customer_type
# Corporate Customer    1   0
# Enterprise Customer   1   0
# Individual Customer  59  70
# MSME                  1   0
# Minor                 0   3
# Salary Customer       1   0
# Youth Corper          8   0

# %%
customer_type_onebank = pd.crosstab(customers_transactions_data['customer_type'],customers_transactions_data['onebank'])
customer_type_onebank.div(customer_type.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='customer_type'>

# %%
cutomer_type_onebank = pd.crosstab(customers_transactions_data['customer_type'], customers_transactions_data['onebank'])
customer_type_onebank
# Out:
# onebank                0   1
# customer_type
# Corporate Customer     1   0
# Enterprise Customer    1   0
# Individual Customer  102  27
# MSME                   1   0
# Minor                  3   0
# Salary Customer        1   0
# Youth Corper           8   0

# %%
customer_type_onepay = pd.crosstab(customers_transactions_data['customer_type'], customers_transactions_data['onepay'])
customer_type_onepay.div(customer_type.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='customer_type'>

# %%
cutomer_type_onepay = pd.crosstab(customers_transactions_data['customer_type'], customers_transactions_data['onepay'])
customer_type_onepay
# Out:
# onepay                0   1
# customer_type
# Corporate Customer    1   0
# Enterprise Customer   1   0
# Individual Customer  57  72
# MSME                  1   0
# Minor                 0   3
# Salary Customer       0   1
# Youth Corper          8   0

# %%
product_group = pd.crosstab(customers_transactions_data['product_group_desc'],customers_transactions_data['account_status'])
product_group.div(product_group.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,6))
# Out:
# <Axes: xlabel='product_group_desc'>

# %%
product_group = pd.crosstab(customers_transactions_data['product_group_desc'],customers_transactions_data['account_status'])
product_group
# Out:
# account_status          Active  Dormant  Inactive
# product_group_desc
# Current Accounts Group       2       23         2
# Savings Accounts Group       2       48        67
